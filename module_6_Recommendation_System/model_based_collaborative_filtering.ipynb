# %%
from surprise import Dataset, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
# Out:
# The kernel failed to start as the Python Environment 'Python 3.11.7' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# Load MovieLens 100k dataset
data = Dataset.load_builtin('ml-100k')
trainset, testset = train_test_split(data, test_size=0.25)

# %%
# Train SVD model
model = SVD(n_factors=50, lr_all=0.005, reg_all=0.02)
model.fit(trainset)

# %%
# Predict ratings for test set
predictions = model.test(testset)

# %%
# Evaluate RMSE
rmse = accuracy.rmse(predictions)
print("Test RMSE:", rmse)

# %%
# Predict rating for user 1 on item 50
predicted_rating = model.predict(uid=1, iid=50).est
print("Predicted rating for user 1 on item 50:", predicted_rating)
